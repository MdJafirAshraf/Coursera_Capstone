# %% [markdown]
# <center><h1>Exploratory Data Analysis</h1></center>

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
mpl.style.use('ggplot')
# %matplotlib inline

# %%
#read the new data
df = pd.read_csv("new_data_collisions.csv")
df.head()
# Out:
#    SEVERITYCODE  OBJECTID  INCKEY  STATUS  ADDRTYPE  COLLISIONTYPE  \
# 0             2         1    1307       0         2              0
# 1             1         2   52200       0         1              9
# 2             1         3   26700       0         1              5
# 3             1         4    1144       0         1              4
# 4             2         5   17700       0         2              0
#
#    PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  JUNCTIONTYPE  WEATHER  \
# 0            2         0            0         2             1        4
# 1            2         0            0         2             4        6
# 2            4         0            0         3             4        4
# 3            3         0            0         3             4        1
# 4            2         0            0         2             1        6
#
#    ROADCOND  LIGHTCOND ST_COLCODE
# 0         8          5         10
# 1         8          2         11
# ...

# %%
sns.countplot(df['SEVERITYCODE'], data=df)

# %%
sns.countplot(df['STATUS'], data=df)

# %%
sns.countplot(df['ADDRTYPE'], data=df)

# %%
sns.countplot(df['PEDCOUNT'], data=df)

# %%
sns.countplot(df['PEDCYLCOUNT'], data=df)

# %%
sns.heatmap(df.corr(),cmap="YlGnBu", square=True, annot=None)

# %%
sns.pairplot(df[['ADDRTYPE','COLLISIONTYPE','JUNCTIONTYPE']])

# %%
df_1 = df[['SEVERITYCODE','STATUS','ADDRTYPE','COLLISIONTYPE','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT','JUNCTIONTYPE','WEATHER','ROADCOND','LIGHTCOND']]

# %%
df.plot(kind='hist',figsize=(10, 6), alpha=0.5)
